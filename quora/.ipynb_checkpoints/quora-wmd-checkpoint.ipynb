# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from nltk.corpus import stopwords
import numpy as np
from gensim.models.wrappers.fasttext import FastTextKeyedVectors
from nltk import word_tokenize
import subprocess
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Data read

# %%
df = pd.read_csv('data/quora-train.csv')
df = df.fillna('a')

# %% [markdown]
# ### FastText + Gensim sex

# %%
FASTTEXT_EXECUTABLE = 'fasttext'
PRETRAINED_MODEL_FILE = 'model/fasttext/wiki.en.bin'
VOCAB_FILE = 'model/fasttext/quora.vocab'
OUTPUT_FILE = 'model/fasttext/quora.vec'
EMBEDDING_DIM = 300

# %%
all_words = set(word_tokenize('\n'.join(list(df.question1) + list(df.question2)).lower()))
all_words.add("<pad>")

# %%
with open(VOCAB_FILE, 'w') as f:
    for word in all_words:
        f.write(word + "\n")

# %%
# !rm model/fasttext/quora.vec

# %%
with open(VOCAB_FILE) as f_vocab:
    with open(OUTPUT_FILE, 'a') as f_output:
        print(f'{len(all_words)} {EMBEDDING_DIM}', file=f_output)
        subprocess.run(
            [FASTTEXT_EXECUTABLE, 'print-word-vectors', PRETRAINED_MODEL_FILE],
            stdin=f_vocab,
            stdout=f_output,
        )

# %%
with open(OUTPUT_FILE, 'r+') as f:
    content = f.read()
    f.seek(0, 0)
    print(f'{len(all_words)} {EMBEDDING_DIM}\n{content}', file=f)

# %% [markdown]
# ### Model

# %%
model = FastTextKeyedVectors.load_word2vec_format('model/fasttext/quora.vec')

# %%
model.vocab
# Out:
# {'/it': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad320>,
#  'kroes': <gensim.models.keyedvectors.Vocab at 0x7f727c1767b8>,
#  'x^2−x−4': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae080>,
#  'olivetti': <gensim.models.keyedvectors.Vocab at 0x7f727c172358>,
#  'scala+akka': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae0f0>,
#  'dragging': <gensim.models.keyedvectors.Vocab at 0x7f727c1725f8>,
#  'needing': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae128>,
#  'squeezed': <gensim.models.keyedvectors.Vocab at 0x7f727c172780>,
#  'fiiitjee': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae160>,
#  'downoad': <gensim.models.keyedvectors.Vocab at 0x7f727c1727f0>,
#  'salish': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae278>,
#  'stargardt': <gensim.models.keyedvectors.Vocab at 0x7f727c172860>,
#  'by…': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae2b0>,
#  'hernia.july': <gensim.models.keyedvectors.Vocab at 0x7f727c172908>,
#  '650-155': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae2e8>,
#  'position.i': <gensim.models.keyedvectors.Vocab at 0x7f727c172a90>,
#  'rapidminer': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae320>,
#  '3x7': <gensim.models.keyedvectors.Vocab at 0x7f727c172940>,
#  'lyrical': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae4a8>,
#  '134': <gensim.models.keyedvectors.Vocab at 0x7f727c172b00>,
#  'neg': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae5c0>,
#  'penitentiary': <gensim.models.keyedvectors.Vocab at 0x7f727c172c88>,
#  'terminally': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae5f8>,
#  'govindpuri': <gensim.models.keyedvectors.Vocab at 0x7f727c172cc0>,
#  'ibc': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae630>,
#  'azure': <gensim.models.keyedvectors.Vocab at 0x7f727c172e10>,
#  'impeding': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae6a0>,
#  'permantley': <gensim.models.keyedvectors.Vocab at 0x7f727c172dd8>,
#  'lifestyles': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae6d8>,
#  'luggage/hand': <gensim.models.keyedvectors.Vocab at 0x7f727c172e48>,
#  'staad': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae710>,
#  'gear-shifting': <gensim.models.keyedvectors.Vocab at 0x7f727c172f60>,
#  'vuejs': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae748>,
#  '∫f': <gensim.models.keyedvectors.Vocab at 0x7f727c172fd0>,
#  "'likers": <gensim.models.keyedvectors.Vocab at 0x7f727c1ae780>,
#  'diaries': <gensim.models.keyedvectors.Vocab at 0x7f727c1724a8>,
#  'outdoorbillboard.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae898>,
#  'intervening': <gensim.models.keyedvectors.Vocab at 0x7f727c1725c0>,
#  '与己方便': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae940>,
#  't-score': <gensim.models.keyedvectors.Vocab at 0x7f727c172278>,
#  'quintessentially': <gensim.models.keyedvectors.Vocab at 0x7f727c1ae9b0>,
#  '.tir': <gensim.models.keyedvectors.Vocab at 0x7f727c1722b0>,
#  'frehman': <gensim.models.keyedvectors.Vocab at 0x7f727c1aea58>,
#  'non-adult': <gensim.models.keyedvectors.Vocab at 0x7f727c1724e0>,
#  'temperament': <gensim.models.keyedvectors.Vocab at 0x7f727c1aea90>,
#  'kaif': <gensim.models.keyedvectors.Vocab at 0x7f727c172390>,
#  'phone-calls': <gensim.models.keyedvectors.Vocab at 0x7f727c1aeb00>,
#  'swayam': <gensim.models.keyedvectors.Vocab at 0x7f727c172198>,
#  'königsberg': <gensim.models.keyedvectors.Vocab at 0x7f727c1aeb70>,
#  'susitna': <gensim.models.keyedvectors.Vocab at 0x7f727c174ef0>,
#  'mortals': <gensim.models.keyedvectors.Vocab at 0x7f727c1aebe0>,
#  'nipples': <gensim.models.keyedvectors.Vocab at 0x7f727c174828>,
#  'wista': <gensim.models.keyedvectors.Vocab at 0x7f727c1aec50>,
#  'eliminate': <gensim.models.keyedvectors.Vocab at 0x7f727c174c88>,
#  'dishwasher': <gensim.models.keyedvectors.Vocab at 0x7f727c1aec88>,
#  'iops': <gensim.models.keyedvectors.Vocab at 0x7f727c174710>,
#  "'alt-right": <gensim.models.keyedvectors.Vocab at 0x7f727c1aed30>,
#  'academica': <gensim.models.keyedvectors.Vocab at 0x7f727c174cc0>,
#  'yield/kiloton': <gensim.models.keyedvectors.Vocab at 0x7f727c1aeda0>,
#  'valparaiso': <gensim.models.keyedvectors.Vocab at 0x7f727c174f28>,
#  'sulphuric': <gensim.models.keyedvectors.Vocab at 0x7f727c1aedd8>,
#  '1300d': <gensim.models.keyedvectors.Vocab at 0x7f727c174588>,
#  'chops': <gensim.models.keyedvectors.Vocab at 0x7f727c1aeeb8>,
#  'itwill': <gensim.models.keyedvectors.Vocab at 0x7f727c174400>,
#  'pmsby': <gensim.models.keyedvectors.Vocab at 0x7f727c1aef60>,
#  '13000-13500': <gensim.models.keyedvectors.Vocab at 0x7f727c174080>,
#  'downward-sloping': <gensim.models.keyedvectors.Vocab at 0x7f727c1aef98>,
#  'fanspage': <gensim.models.keyedvectors.Vocab at 0x7f727c1740f0>,
#  'party/celebration': <gensim.models.keyedvectors.Vocab at 0x7f727c1aefd0>,
#  'devmountain': <gensim.models.keyedvectors.Vocab at 0x7f727c1741d0>,
#  'rainforest': <gensim.models.keyedvectors.Vocab at 0x7f727c1aeef0>,
#  'ultra-rich': <gensim.models.keyedvectors.Vocab at 0x7f727c1740b8>,
#  'crematories': <gensim.models.keyedvectors.Vocab at 0x7f727c16e748>,
#  'bloc': <gensim.models.keyedvectors.Vocab at 0x7f727c174390>,
#  '3/16': <gensim.models.keyedvectors.Vocab at 0x7f727c16e780>,
#  'single-cell': <gensim.models.keyedvectors.Vocab at 0x7f727c1742e8>,
#  'bhaijaan': <gensim.models.keyedvectors.Vocab at 0x7f727c16e9b0>,
#  'fried-rice': <gensim.models.keyedvectors.Vocab at 0x7f727c1746d8>,
#  "'personal": <gensim.models.keyedvectors.Vocab at 0x7f727c16ea20>,
#  'villians': <gensim.models.keyedvectors.Vocab at 0x7f727c1742b0>,
#  'saxony': <gensim.models.keyedvectors.Vocab at 0x7f727c16e940>,
#  'ayurwin': <gensim.models.keyedvectors.Vocab at 0x7f727c1744e0>,
#  'elitify.com': <gensim.models.keyedvectors.Vocab at 0x7f72895d47b8>,
#  'regurding': <gensim.models.keyedvectors.Vocab at 0x7f727c174518>,
#  'friends.': <gensim.models.keyedvectors.Vocab at 0x7f72895d45f8>,
#  'quant.': <gensim.models.keyedvectors.Vocab at 0x7f727c1746a0>,
#  'labelled': <gensim.models.keyedvectors.Vocab at 0x7f72895d4828>,
#  '8k': <gensim.models.keyedvectors.Vocab at 0x7f727c174358>,
#  'lamo': <gensim.models.keyedvectors.Vocab at 0x7f72895d4860>,
#  'reimbursement': <gensim.models.keyedvectors.Vocab at 0x7f72a1b5b438>,
#  'scarf-like': <gensim.models.keyedvectors.Vocab at 0x7f72895d4940>,
#  'descendant': <gensim.models.keyedvectors.Vocab at 0x7f727c170908>,
#  'minimizing': <gensim.models.keyedvectors.Vocab at 0x7f72895d4630>,
#  'universtiy': <gensim.models.keyedvectors.Vocab at 0x7f727c170278>,
#  'plan': <gensim.models.keyedvectors.Vocab at 0x7f72895d4908>,
#  'mig-35': <gensim.models.keyedvectors.Vocab at 0x7f727c170ba8>,
#  'barge': <gensim.models.keyedvectors.Vocab at 0x7f727c1761d0>,
#  'added/removed': <gensim.models.keyedvectors.Vocab at 0x7f727c170eb8>,
#  'hi..all': <gensim.models.keyedvectors.Vocab at 0x7f727c1762b0>,
#  'stereotyped': <gensim.models.keyedvectors.Vocab at 0x7f727c1709b0>,
#  'mooney': <gensim.models.keyedvectors.Vocab at 0x7f727c176160>,
#  'spider-man/x-men': <gensim.models.keyedvectors.Vocab at 0x7f727c170208>,
#  'christmas': <gensim.models.keyedvectors.Vocab at 0x7f727c176b38>,
#  'safes': <gensim.models.keyedvectors.Vocab at 0x7f727c170ac8>,
#  '=10': <gensim.models.keyedvectors.Vocab at 0x7f727c176ba8>,
#  'mettle': <gensim.models.keyedvectors.Vocab at 0x7f727c1704e0>,
#  'whitehat': <gensim.models.keyedvectors.Vocab at 0x7f727c176c50>,
#  'sassanids': <gensim.models.keyedvectors.Vocab at 0x7f727c170198>,
#  'membership': <gensim.models.keyedvectors.Vocab at 0x7f727c176c88>,
#  'medieval/fantasy': <gensim.models.keyedvectors.Vocab at 0x7f727c1709e8>,
#  'cyberspace': <gensim.models.keyedvectors.Vocab at 0x7f727c176cf8>,
#  'picoseconds': <gensim.models.keyedvectors.Vocab at 0x7f727c170b00>,
#  'ze550kl-1a111in': <gensim.models.keyedvectors.Vocab at 0x7f727c176d30>,
#  'capacitive': <gensim.models.keyedvectors.Vocab at 0x7f727c170c88>,
#  'nemerle': <gensim.models.keyedvectors.Vocab at 0x7f727c176d68>,
#  'glare': <gensim.models.keyedvectors.Vocab at 0x7f727c170e10>,
#  'transmitter': <gensim.models.keyedvectors.Vocab at 0x7f727c176e10>,
#  'harmonious': <gensim.models.keyedvectors.Vocab at 0x7f727c1705c0>,
#  'explaination': <gensim.models.keyedvectors.Vocab at 0x7f727c176e80>,
#  'a+': <gensim.models.keyedvectors.Vocab at 0x7f727c170438>,
#  'clay': <gensim.models.keyedvectors.Vocab at 0x7f727c176f28>,
#  'wales': <gensim.models.keyedvectors.Vocab at 0x7f727c1706d8>,
#  '30secs': <gensim.models.keyedvectors.Vocab at 0x7f727c1780b8>,
#  'proschool': <gensim.models.keyedvectors.Vocab at 0x7f7293a94780>,
#  'retractable': <gensim.models.keyedvectors.Vocab at 0x7f727c178160>,
#  'vietnamization': <gensim.models.keyedvectors.Vocab at 0x7f727c170518>,
#  'shakitmaan': <gensim.models.keyedvectors.Vocab at 0x7f727c178198>,
#  'chives': <gensim.models.keyedvectors.Vocab at 0x7f7293b8d908>,
#  'permanante': <gensim.models.keyedvectors.Vocab at 0x7f727c178278>,
#  'cunha': <gensim.models.keyedvectors.Vocab at 0x7f7293b8d9b0>,
#  'jetliners': <gensim.models.keyedvectors.Vocab at 0x7f727c178358>,
#  'rlh': <gensim.models.keyedvectors.Vocab at 0x7f727c16e160>,
#  "'kafir": <gensim.models.keyedvectors.Vocab at 0x7f727c178470>,
#  'flicked': <gensim.models.keyedvectors.Vocab at 0x7f727c16e048>,
#  "'wants": <gensim.models.keyedvectors.Vocab at 0x7f727c178518>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7f727c16eb00>,
#  'webassign.net': <gensim.models.keyedvectors.Vocab at 0x7f727c1785f8>,
#  'testicles': <gensim.models.keyedvectors.Vocab at 0x7f727c16ec88>,
#  '35000ft': <gensim.models.keyedvectors.Vocab at 0x7f727c178630>,
#  'sapientnitro': <gensim.models.keyedvectors.Vocab at 0x7f727c16ecc0>,
#  'a.m.i.e': <gensim.models.keyedvectors.Vocab at 0x7f727c178668>,
#  'i.t': <gensim.models.keyedvectors.Vocab at 0x7f727c16ebe0>,
#  'evaporates': <gensim.models.keyedvectors.Vocab at 0x7f727c178748>,
#  'raag': <gensim.models.keyedvectors.Vocab at 0x7f727c16e4a8>,
#  'life.can': <gensim.models.keyedvectors.Vocab at 0x7f727c1789b0>,
#  'personals': <gensim.models.keyedvectors.Vocab at 0x7f727c16eb70>,
#  'kitna..an': <gensim.models.keyedvectors.Vocab at 0x7f727c1789e8>,
#  'prossesor': <gensim.models.keyedvectors.Vocab at 0x7f727c178b38>,
#  'genitals': <gensim.models.keyedvectors.Vocab at 0x7f727c178a20>,
#  'bornvita': <gensim.models.keyedvectors.Vocab at 0x7f727c178c18>,
#  'employability': <gensim.models.keyedvectors.Vocab at 0x7f727c178a58>,
#  'sterk': <gensim.models.keyedvectors.Vocab at 0x7f727c178c88>,
#  'proff': <gensim.models.keyedvectors.Vocab at 0x7f727c178ac8>,
#  'spacemacs': <gensim.models.keyedvectors.Vocab at 0x7f727c178da0>,
#  'misrepresentation': <gensim.models.keyedvectors.Vocab at 0x7f727c178a90>,
#  'valuecart': <gensim.models.keyedvectors.Vocab at 0x7f727c178dd8>,
#  'judi': <gensim.models.keyedvectors.Vocab at 0x7f727c17a588>,
#  'show-': <gensim.models.keyedvectors.Vocab at 0x7f727c178f28>,
#  'cuckoo': <gensim.models.keyedvectors.Vocab at 0x7f727c17a668>,
#  'cervantes': <gensim.models.keyedvectors.Vocab at 0x7f727c178898>,
#  'fewh': <gensim.models.keyedvectors.Vocab at 0x7f727c17a748>,
#  'butterfly': <gensim.models.keyedvectors.Vocab at 0x7f727c178940>,
#  'brown-eyed': <gensim.models.keyedvectors.Vocab at 0x7f727c17a860>,
#  'peed': <gensim.models.keyedvectors.Vocab at 0x7f727c178908>,
#  'discourse': <gensim.models.keyedvectors.Vocab at 0x7f727c17add8>,
#  'burqa': <gensim.models.keyedvectors.Vocab at 0x7f727c17a940>,
#  'darkness': <gensim.models.keyedvectors.Vocab at 0x7f727c17af28>,
#  'tin': <gensim.models.keyedvectors.Vocab at 0x7f727c17a9e8>,
#  'ower': <gensim.models.keyedvectors.Vocab at 0x7f727c17aba8>,
#  'informer': <gensim.models.keyedvectors.Vocab at 0x7f727c17aa58>,
#  'm3m': <gensim.models.keyedvectors.Vocab at 0x7f727c17a240>,
#  'canot': <gensim.models.keyedvectors.Vocab at 0x7f727c17a080>,
#  'pima': <gensim.models.keyedvectors.Vocab at 0x7f727c17a320>,
#  '1611': <gensim.models.keyedvectors.Vocab at 0x7f727c17a1d0>,
#  'crv': <gensim.models.keyedvectors.Vocab at 0x7f727c17a390>,
#  'mentorship': <gensim.models.keyedvectors.Vocab at 0x7f727c17a4e0>,
#  'ishq': <gensim.models.keyedvectors.Vocab at 0x7f727c17a438>,
#  'bearish': <gensim.models.keyedvectors.Vocab at 0x7f727c17aac8>,
#  'likhari': <gensim.models.keyedvectors.Vocab at 0x7f727c17abe0>,
#  'wikitude': <gensim.models.keyedvectors.Vocab at 0x7f727c17a208>,
#  'asteroid': <gensim.models.keyedvectors.Vocab at 0x7f727c17ac18>,
#  'research/internships': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac208>,
#  'sensing': <gensim.models.keyedvectors.Vocab at 0x7f727c17acc0>,
#  're-sale': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac358>,
#  'arrear': <gensim.models.keyedvectors.Vocab at 0x7f727c17a278>,
#  'n-i': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac3c8>,
#  'incites': <gensim.models.keyedvectors.Vocab at 0x7f727c17a2b0>,
#  'proficiently': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac780>,
#  'pakistan-occupied': <gensim.models.keyedvectors.Vocab at 0x7f727c1acba8>,
#  'poji': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac7f0>,
#  'nephews': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac5f8>,
#  'sora': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac748>,
#  'excretory': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac668>,
#  'lush': <gensim.models.keyedvectors.Vocab at 0x7f727c1accc0>,
#  'cylinders': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac828>,
#  'buddhist': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac080>,
#  'mercedes-benz': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac898>,
#  'clerk.which': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac0b8>,
#  'novelist': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac978>,
#  'disagreement': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac160>,
#  'vvip': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac9b0>,
#  'dunkin': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad6a0>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac6a0>,
#  'nomadic': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad400>,
#  '6140': <gensim.models.keyedvectors.Vocab at 0x7f727c1ace10>,
#  'motivational': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad828>,
#  'see/do/eat': <gensim.models.keyedvectors.Vocab at 0x7f727c1ace48>,
#  '750lim': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad8d0>,
#  'solano': <gensim.models.keyedvectors.Vocab at 0x7f727c1acf60>,
#  'spear': <gensim.models.keyedvectors.Vocab at 0x7f727c1adac8>,
#  'flirts': <gensim.models.keyedvectors.Vocab at 0x7f727c1acf98>,
#  'fast-paced': <gensim.models.keyedvectors.Vocab at 0x7f727c1adb38>,
#  'zulu': <gensim.models.keyedvectors.Vocab at 0x7f727c1acfd0>,
#  'smaller/weaker': <gensim.models.keyedvectors.Vocab at 0x7f727c1adc50>,
#  'pcc': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac048>,
#  'wysiwyg': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad5c0>,
#  'getting-to-know-each-other': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac4a8>,
#  'fenga': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad5f8>,
#  'racist/sexist/islamophobic': <gensim.models.keyedvectors.Vocab at 0x7f727c1ac438>,
#  'plasmas': <gensim.models.keyedvectors.Vocab at 0x7f727c1ade48>,
#  'assaulting': <gensim.models.keyedvectors.Vocab at 0x7f727c1adc88>,
#  'likeif': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad978>,
#  'fav': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad748>,
#  'gunfights': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad198>,
#  'badí': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad7b8>,
#  'amylopectin': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad208>,
#  '3blue1brown': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad7f0>,
#  'assassinate': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad160>,
#  'trade/ablaze': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad390>,
#  'aashiqui': <gensim.models.keyedvectors.Vocab at 0x7f727c1af9e8>,
#  'boruto-naruto': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad3c8>,
#  'mehrab': <gensim.models.keyedvectors.Vocab at 0x7f727c1afac8>,
#  'granite': <gensim.models.keyedvectors.Vocab at 0x7f727c1adba8>,
#  'bureaucrats': <gensim.models.keyedvectors.Vocab at 0x7f727c1afb38>,
#  '.json': <gensim.models.keyedvectors.Vocab at 0x7f727c1adbe0>,
#  'paroled': <gensim.models.keyedvectors.Vocab at 0x7f727c1afe80>,
#  'teracopy': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad358>,
#  'daydreams': <gensim.models.keyedvectors.Vocab at 0x7f727c1aff28>,
#  'sedans': <gensim.models.keyedvectors.Vocab at 0x7f727c1adcf8>,
#  'chechnya': <gensim.models.keyedvectors.Vocab at 0x7f727c1af240>,
#  'obstruction': <gensim.models.keyedvectors.Vocab at 0x7f727c1add30>,
#  'personality-wise': <gensim.models.keyedvectors.Vocab at 0x7f727c1af278>,
#  'drone/quadcopter': <gensim.models.keyedvectors.Vocab at 0x7f727c1adf98>,
#  'vaccination': <gensim.models.keyedvectors.Vocab at 0x7f727c1af2e8>,
#  'batman.js': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad080>,
#  'incl': <gensim.models.keyedvectors.Vocab at 0x7f727c1af908>,
#  '3.1': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad4a8>,
#  'rage': <gensim.models.keyedvectors.Vocab at 0x7f727c1af518>,
#  'interviewing': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad240>,
#  'archery': <gensim.models.keyedvectors.Vocab at 0x7f727c1af588>,
#  'morphosyntactic': <gensim.models.keyedvectors.Vocab at 0x7f727c1ad278>,
#  'assert': <gensim.models.keyedvectors.Vocab at 0x7f727c1af6a0>,
#  'obtuse': <gensim.models.keyedvectors.Vocab at 0x7f727c1af3c8>,
#  'breathless': <gensim.models.keyedvectors.Vocab at 0x7f727c1af780>,
#  'initiates': <gensim.models.keyedvectors.Vocab at 0x7f727c1af940>,
#  '2/4': <gensim.models.keyedvectors.Vocab at 0x7f727c1af7b8>,
#  'reincarnate': <gensim.models.keyedvectors.Vocab at 0x7f727c1af0b8>,
#  'supremacy': <gensim.models.keyedvectors.Vocab at 0x7f727c1af7f0>,
#  'q84000': <gensim.models.keyedvectors.Vocab at 0x7f727c1afb70>,
#  'enterprise': <gensim.models.keyedvectors.Vocab at 0x7f727c1afd68>,
#  'migrations': <gensim.models.keyedvectors.Vocab at 0x7f727c1afba8>,
#  "'prenant": <gensim.models.keyedvectors.Vocab at 0x7f727c1afda0>,
#  'eu1000i': <gensim.models.keyedvectors.Vocab at 0x7f727c1afcc0>,
#  'wabash': <gensim.models.keyedvectors.Vocab at 0x7f727c1af160>,
#  'bhaav': <gensim.models.keyedvectors.Vocab at 0x7f727c1af898>,
#  'intern/job': <gensim.models.keyedvectors.Vocab at 0x7f727c1af860>,
#  'workings': <gensim.models.keyedvectors.Vocab at 0x7f727c1afcf8>,
#  'y,0': <gensim.models.keyedvectors.Vocab at 0x7f727c1af8d0>,
#  '98.338': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0240>,
#  'sphr': <gensim.models.keyedvectors.Vocab at 0x7f727c1af208>,
#  '86': <gensim.models.keyedvectors.Vocab at 0x7f727c1b02b0>,
#  'doesi': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0c88>,
#  'roger': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0358>,
#  'sides/lanes': <gensim.models.keyedvectors.Vocab at 0x7f727c1b01d0>,
#  'hilar': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0908>,
#  'gleason': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0668>,
#  'defragmenter': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0978>,
#  'car-renting': <gensim.models.keyedvectors.Vocab at 0x7f727c1b06a0>,
#  'peanut': <gensim.models.keyedvectors.Vocab at 0x7f727c1b09b0>,
#  'palihapitiya': <gensim.models.keyedvectors.Vocab at 0x7f727c1b09e8>,
#  'cubes.out': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0390>,
#  'irreversible': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0a90>,
#  'forklift': <gensim.models.keyedvectors.Vocab at 0x7f727c1b03c8>,
#  'destroyers': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0ac8>,
#  'muscaria': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0400>,
#  'jali': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0b38>,
#  'costumer': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0710>,
#  'franks': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0470>,
#  'infanticide': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0160>,
#  'canoe': <gensim.models.keyedvectors.Vocab at 0x7f727c1b04a8>,
#  'bobbles': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0dd8>,
#  'fugu': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0ba8>,
#  'buissness': <gensim.models.keyedvectors.Vocab at 0x7f727c1b08d0>,
#  'einthusan.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0f98>,
#  'reading/studying': <gensim.models.keyedvectors.Vocab at 0x7f727c1b00b8>,
#  'tokyo': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0780>,
#  'armitron': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0630>,
#  '10:30pm-11:40am': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0be0>,
#  '-40°c': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0e48>,
#  'core-mark': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0080>,
#  'anchovies': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0eb8>,
#  'anaerobes': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0b00>,
#  'facture': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0ef0>,
#  'iralos': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1128>,
#  'impersonates': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0cf8>,
#  'necrosis': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1160>,
#  'commanders': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0d30>,
#  'blast': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1208>,
#  'chihuahuan': <gensim.models.keyedvectors.Vocab at 0x7f727c1b0f60>,
#  'reread': <gensim.models.keyedvectors.Vocab at 0x7f727c1b12b0>,
#  'megabits': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1c88>,
#  'site-merchandiser': <gensim.models.keyedvectors.Vocab at 0x7f727c1b12e8>,
#  'puck': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1cf8>,
#  'intj': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1390>,
#  'jojen': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1dd8>,
#  'high-income': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1400>,
#  'naturalism': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1e10>,
#  'tica': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1438>,
#  'optcl': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1e80>,
#  'proofpoint': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1ba8>,
#  'lawyers/': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1f60>,
#  'ivys': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1c18>,
#  'mothership': <gensim.models.keyedvectors.Vocab at 0x7f727c1b15c0>,
#  'training/certification': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1b70>,
#  'al-ghaib': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1668>,
#  'over-consuming': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2080>,
#  'semantically': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1a58>,
#  'martins': <gensim.models.keyedvectors.Vocab at 0x7f727c1b20b8>,
#  'dances': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1f98>,
#  'chamfered': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2160>,
#  'eea': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1fd0>,
#  'finished': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2940>,
#  '1z0-510': <gensim.models.keyedvectors.Vocab at 0x7f727c1b19b0>,
#  'slavics': <gensim.models.keyedvectors.Vocab at 0x7f727c1b25c0>,
#  'godavari': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1278>,
#  'prabhu': <gensim.models.keyedvectors.Vocab at 0x7f727c1b25f8>,
#  'spanks': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1828>,
#  "'disturb": <gensim.models.keyedvectors.Vocab at 0x7f727c1b2fd0>,
#  'exorcism': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1978>,
#  'eu/europe': <gensim.models.keyedvectors.Vocab at 0x7f727c1b20f0>,
#  "'shirkhurma": <gensim.models.keyedvectors.Vocab at 0x7f727c1b16d8>,
#  '99.28': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2128>,
#  'backend': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1748>,
#  '4-5hrs': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2860>,
#  'airbar': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1550>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x7f727c1b28d0>,
#  'kitwall.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1780>,
#  'arial': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2908>,
#  'manjam': <gensim.models.keyedvectors.Vocab at 0x7f727c1b17f0>,
#  'spectators': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2c50>,
#  'designing.should': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1860>,
#  'sucessfully': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2c88>,
#  'follow/know': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1898>,
#  '451': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2cf8>,
#  '8.': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1908>,
#  '1.12587': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2da0>,
#  'koruna': <gensim.models.keyedvectors.Vocab at 0x7f727c1b1940>,
#  'cash': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2668>,
#  'xvi': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2ac8>,
#  'printout': <gensim.models.keyedvectors.Vocab at 0x7f727c1b26d8>,
#  '1280.': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2b00>,
#  'systemcare': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2c18>,
#  'utorrent': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2b38>,
#  'coordinator': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2e48>,
#  '208y/120v': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2ba8>,
#  '4v': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2780>,
#  'millsberry.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2358>,
#  'economy': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2400>,
#  'mfcc': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3630>,
#  'mkcg': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2518>,
#  'ramaih': <gensim.models.keyedvectors.Vocab at 0x7f727c1b36d8>,
#  'unstoppables': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2588>,
#  'pentaxim': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3710>,
#  '1957': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2f28>,
#  'kalila': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3780>,
#  'rcbs': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2278>,
#  'www.indianlisted.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1b37f0>,
#  'nthan': <gensim.models.keyedvectors.Vocab at 0x7f727c1b22b0>,
#  '2/native': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3898>,
#  'unworn': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2320>,
#  'cazpro.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3a58>,
#  'ras': <gensim.models.keyedvectors.Vocab at 0x7f727c1b2240>,
#  'nseit': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3ac8>,
#  'buck-boost': <gensim.models.keyedvectors.Vocab at 0x7f727c1b32e8>,
#  'collie/golden': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3b00>,
#  'quirrel': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3320>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3d30>,
#  'circumambulate': <gensim.models.keyedvectors.Vocab at 0x7f727c1b33c8>,
#  'dianne': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3b38>,
#  '14:55pm': <gensim.models.keyedvectors.Vocab at 0x7f727c1b39e8>,
#  'false.explain': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4860>,
#  'hyperpigmentation': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3a20>,
#  'visits': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4908>,
#  'forensics': <gensim.models.keyedvectors.Vocab at 0x7f727c1b30b8>,
#  'congratulate': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4940>,
#  'satelttite': <gensim.models.keyedvectors.Vocab at 0x7f727c1b30f0>,
#  'allocative': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4320>,
#  'advertising-tech': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3cc0>,
#  'blinds': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4390>,
#  'multidiscipline': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3518>,
#  'gothra': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4438>,
#  'خلوة': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3e80>,
#  'khidirpur': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4b70>,
#  'of-ten': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3c18>,
#  'tna': <gensim.models.keyedvectors.Vocab at 0x7f727c1b40b8>,
#  'oz': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3240>,
#  'hight': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4c88>,
#  'perfection': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3550>,
#  'francisco': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4d30>,
#  'bitsian': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3908>,
#  'akand': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4e80>,
#  'whichi': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3978>,
#  'pramotion': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4ef0>,
#  'oscilloscopes': <gensim.models.keyedvectors.Vocab at 0x7f727c1b39b0>,
#  'signal': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4f28>,
#  'granular': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3fd0>,
#  'alto/mountain': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4fd0>,
#  "'ra": <gensim.models.keyedvectors.Vocab at 0x7f727c1b3d68>,
#  'rappers/artists': <gensim.models.keyedvectors.Vocab at 0x7f727c1b44e0>,
#  'quintessential': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3da0>,
#  'vronsky': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4550>,
#  'koh-i-noor': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3c88>,
#  'hkd': <gensim.models.keyedvectors.Vocab at 0x7f727c1b45c0>,
#  'germany..': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3be0>,
#  'crisprs': <gensim.models.keyedvectors.Vocab at 0x7f727c1b45f8>,
#  'mckinsey/bain/bcg': <gensim.models.keyedvectors.Vocab at 0x7f727c1b3ef0>,
#  '1.29': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4c50>,
#  'details:20/04/78': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4978>,
#  'agent': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4ac8>,
#  'have.adhd': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4278>,
#  'al-bab': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4b00>,
#  'manav': <gensim.models.keyedvectors.Vocab at 0x7f727c1b42e8>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4048>,
#  'forevermore': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4198>,
#  'actinomorphic': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4128>,
#  'investopedia': <gensim.models.keyedvectors.Vocab at 0x7f727c1b41d0>,
#  'aiims/jipmer/nimhans': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4470>,
#  'cheerleading': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4630>,
#  'resizing': <gensim.models.keyedvectors.Vocab at 0x7f727c1b49e8>,
#  'portea': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4160>,
#  'zbiddy': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4668>,
#  'tow\xadards': <gensim.models.keyedvectors.Vocab at 0x7f727c1b59e8>,
#  'kwikset': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4710>,
#  'washerman': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5ac8>,
#  '300rs': <gensim.models.keyedvectors.Vocab at 0x7f727c1b4a20>,
#  'cornville': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5b38>,
#  'suit': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5390>,
#  'faction': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5c18>,
#  'groupon-like': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5438>,
#  'feeble': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5c50>,
#  "'transmission": <gensim.models.keyedvectors.Vocab at 0x7f727c1b5080>,
#  'lean.what': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5c88>,
#  'answers': <gensim.models.keyedvectors.Vocab at 0x7f727c1b54a8>,
#  'curation': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5d68>,
#  'uninvolved': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5550>,
#  'rva': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5240>,
#  'àimèi': <gensim.models.keyedvectors.Vocab at 0x7f727c1b56a0>,
#  "'visual": <gensim.models.keyedvectors.Vocab at 0x7f727c1b5278>,
#  'mail-order': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5470>,
#  'fills': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5da0>,
#  'compulsive': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5780>,
#  'pre-determined': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5dd8>,
#  'lisps': <gensim.models.keyedvectors.Vocab at 0x7f727c1b57b8>,
#  'walled': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5e48>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5828>,
#  'copywriters': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5eb8>,
#  'indirectaly': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5898>,
#  '1.5ghz': <gensim.models.keyedvectors.Vocab at 0x7f727c1b51d0>,
#  'akkadian': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5f98>,
#  'www.imcbusiness.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5208>,
#  'bile': <gensim.models.keyedvectors.Vocab at 0x7f727c1b52e8>,
#  '485+': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5f28>,
#  'el-mahalla': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5630>,
#  'aryan': <gensim.models.keyedvectors.Vocab at 0x7f727c1b57f0>,
#  'cinematography': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5198>,
#  'krabby': <gensim.models.keyedvectors.Vocab at 0x7f727c1b5ef0>,
#  'grovement': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6fd0>,
#  'post-season': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6668>,
#  'aslam': <gensim.models.keyedvectors.Vocab at 0x7f727c1b62e8>,
#  'laton': <gensim.models.keyedvectors.Vocab at 0x7f727c1b66d8>,
#  'dissapointed': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6390>,
#  'panacea': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6470>,
#  'hunt': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6e10>,
#  'words*': <gensim.models.keyedvectors.Vocab at 0x7f727c1b60b8>,
#  'installed': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6eb8>,
#  'zimmerman': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6128>,
#  'rhinovirus': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6198>,
#  'subtitiles': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6710>,
#  'mtt': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6b00>,
#  'becomec': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6908>,
#  '351': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6c88>,
#  'takes': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6278>,
#  'contries': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6d30>,
#  'auto-encoders': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6518>,
#  'dual/triple': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6dd8>,
#  '3x+1+11=-20x+12+16x+16': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6ef0>,
#  'frayed': <gensim.models.keyedvectors.Vocab at 0x7f727c1b61d0>,
#  'emigration': <gensim.models.keyedvectors.Vocab at 0x7f727c1b67b8>,
#  '32b': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6550>,
#  'ugui': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6828>,
#  'llano': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6588>,
#  'eyecolor': <gensim.models.keyedvectors.Vocab at 0x7f727c1b6860>,
#  'distilleries': <gensim.models.keyedvectors.Vocab at 0x7f727c1b64a8>,
#  'similiar': <gensim.models.keyedvectors.Vocab at 0x7f727c1b71d0>,
#  'sensen': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7630>,
#  'expenses/savings': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7240>,
#  'details': <gensim.models.keyedvectors.Vocab at 0x7f727c1b72e8>,
#  "'gay": <gensim.models.keyedvectors.Vocab at 0x7f727c1b72b0>,
#  'punisher': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7358>,
#  'echad': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7c18>,
#  'rlins': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7cc0>,
#  'sharethis.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7c88>,
#  'tunings': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7208>,
#  'sakura': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7710>,
#  'menthol': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7128>,
#  'outplacement': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7780>,
#  'sophists': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7160>,
#  'squadron': <gensim.models.keyedvectors.Vocab at 0x7f727c1b77b8>,
#  'leapure': <gensim.models.keyedvectors.Vocab at 0x7f727c1b74a8>,
#  '16:16': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7860>,
#  'hailin': <gensim.models.keyedvectors.Vocab at 0x7f727c1b76a0>,
#  'commuting': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7470>,
#  'brass': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7da0>,
#  'freakishly': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7e80>,
#  'subnetting': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7908>,
#  'renate': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7ef0>,
#  'turon': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7978>,
#  'otome': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7f98>,
#  "mo'orea": <gensim.models.keyedvectors.Vocab at 0x7f727c1b8978>,
#  'limescale': <gensim.models.keyedvectors.Vocab at 0x7f727c1b79e8>,
#  'attires/dressing': <gensim.models.keyedvectors.Vocab at 0x7f727c1b89b0>,
#  'fixtures': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7a90>,
#  'm750n': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8b00>,
#  'biw': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7b00>,
#  'annaly': <gensim.models.keyedvectors.Vocab at 0x7f727c1b89e8>,
#  'udp/ip': <gensim.models.keyedvectors.Vocab at 0x7f727c1b7be0>,
#  'renok': <gensim.models.keyedvectors.Vocab at 0x7f727c1b85f8>,
#  'gigi': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8e48>,
#  'painstakingly': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8668>,
#  'heterotroph': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8eb8>,
#  'chapo': <gensim.models.keyedvectors.Vocab at 0x7f727c1b86a0>,
#  'thumri': <gensim.models.keyedvectors.Vocab at 0x7f727c1b84a8>,
#  'insensitive': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8d68>,
#  'hammerbacher': <gensim.models.keyedvectors.Vocab at 0x7f727c1b84e0>,
#  'blockchains': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8da0>,
#  'homophobes': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8550>,
#  'whays': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8198>,
#  'julio': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8c50>,
#  'np-completeness': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8a20>,
#  'visibly': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8c88>,
#  'kotetsu': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8ac8>,
#  'myfreecames': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8cf8>,
#  'bizagi': <gensim.models.keyedvectors.Vocab at 0x7f727c1b82b0>,
#  'e-business': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8240>,
#  'hilfinger': <gensim.models.keyedvectors.Vocab at 0x7f727c1b82e8>,
#  '2stroke': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8c18>,
#  "'work'.but": <gensim.models.keyedvectors.Vocab at 0x7f727c1b8358>,
#  'lewandoski': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9f60>,
#  'speckled': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8390>,
#  'male-female': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9f98>,
#  'firmware': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8278>,
#  'useless/lame': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9fd0>,
#  'commercially-friendly': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8748>,
#  'दिन': <gensim.models.keyedvectors.Vocab at 0x7f727c1b99e8>,
#  'avoidable': <gensim.models.keyedvectors.Vocab at 0x7f727c1b87f0>,
#  'aeromodelling': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9a20>,
#  'siddaramaiah': <gensim.models.keyedvectors.Vocab at 0x7f727c1b88d0>,
#  'romanesque': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9588>,
#  'mamoa': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8048>,
#  'amendment': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9400>,
#  'declined': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8080>,
#  'ctab': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9438>,
#  'cse/electrical/mechanical': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8128>,
#  'dadri': <gensim.models.keyedvectors.Vocab at 0x7f727c1b94a8>,
#  'hygienist': <gensim.models.keyedvectors.Vocab at 0x7f727c1b8160>,
#  '22134': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9ba8>,
#  'topguest': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9550>,
#  'bertucci': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9be0>,
#  'dlinlk': <gensim.models.keyedvectors.Vocab at 0x7f727c1b90f0>,
#  'clothing/fashion': <gensim.models.keyedvectors.Vocab at 0x7f727c1b96d8>,
#  'undateable': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9128>,
#  'lewin': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9978>,
#  'time/money': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9198>,
#  'fabros': <gensim.models.keyedvectors.Vocab at 0x7f727c1b99b0>,
#  'tributes': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9240>,
#  'chalk': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9a90>,
#  'creek': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9048>,
#  'threadx': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9b00>,
#  ':4919': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9080>,
#  'literate': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9b70>,
#  'chngng': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9e48>,
#  'culture/food/country': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9d30>,
#  'bodies': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9940>,
#  '5/10/20': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9e80>,
#  'ayodhya': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9da0>,
#  'unchanged': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9748>,
#  'promotion/strategies': <gensim.models.keyedvectors.Vocab at 0x7f727c1b95c0>,
#  'bf4': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9780>,
#  'dimes': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9278>,
#  'tiket.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9898>,
#  'kamehame992': <gensim.models.keyedvectors.Vocab at 0x7f727c1b92b0>,
#  'idioms': <gensim.models.keyedvectors.Vocab at 0x7f727c1b98d0>,
#  'restlessness': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9390>,
#  'evercare': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9860>,
#  'gokano.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1b9320>,
#  'ready-to-use': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba160>,
#  'offer-driven': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba6a0>,
#  'cusomer': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba3c8>,
#  'anti-conservative': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba710>,
#  'clinidipine': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba438>,
#  'sinhalese-peoples': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba748>,
#  'untime': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba828>,
#  'satam': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba208>,
#  "'brahmin": <gensim.models.keyedvectors.Vocab at 0x7f727c1ba8d0>,
#  'replays': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba240>,
#  'swarna': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba588>,
#  'gravidarum': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba320>,
#  'x=2': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba080>,
#  'foetalis': <gensim.models.keyedvectors.Vocab at 0x7f727c1bacc0>,
#  'institute': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba0b8>,
#  'delayed': <gensim.models.keyedvectors.Vocab at 0x7f727c1bad68>,
#  'religare': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba400>,
#  'execution/bombing': <gensim.models.keyedvectors.Vocab at 0x7f727c1bada0>,
#  'horror/thriller': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba048>,
#  'trayvon': <gensim.models.keyedvectors.Vocab at 0x7f727c1bab00>,
#  'jomashop': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba1d0>,
#  'account/user': <gensim.models.keyedvectors.Vocab at 0x7f727c1bab70>,
#  'lìng': <gensim.models.keyedvectors.Vocab at 0x7f727c1baac8>,
#  'uploaded': <gensim.models.keyedvectors.Vocab at 0x7f727c1bae10>,
#  'committiee': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba4a8>,
#  'vision.blobanalysis': <gensim.models.keyedvectors.Vocab at 0x7f727c1babe0>,
#  "'active": <gensim.models.keyedvectors.Vocab at 0x7f727c1ba940>,
#  'coupondunia.in': <gensim.models.keyedvectors.Vocab at 0x7f727c1bcdd8>,
#  'forester': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba9b0>,
#  'f/4.0-5.6g': <gensim.models.keyedvectors.Vocab at 0x7f727c1bce10>,
#  'chou': <gensim.models.keyedvectors.Vocab at 0x7f727c1baa20>,
#  'outsmarting': <gensim.models.keyedvectors.Vocab at 0x7f727c1bcba8>,
#  'parking': <gensim.models.keyedvectors.Vocab at 0x7f727c1baa58>,
#  'fortified': <gensim.models.keyedvectors.Vocab at 0x7f727c1bcc18>,
#  '505': <gensim.models.keyedvectors.Vocab at 0x7f727c1baa90>,
#  'oxidize': <gensim.models.keyedvectors.Vocab at 0x7f727c1bcc88>,
#  'earnings': <gensim.models.keyedvectors.Vocab at 0x7f727c1ba390>,
#  'mcphs': <gensim.models.keyedvectors.Vocab at 0x7f727c1bccc0>,
#  'janszoon': <gensim.models.keyedvectors.Vocab at 0x7f727c1bae80>,
#  'shire': <gensim.models.keyedvectors.Vocab at 0x7f727c1bccf8>,
#  'pattanaik': <gensim.models.keyedvectors.Vocab at 0x7f727c1baf60>,
#  'instream': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc7f0>,
#  'lyrics': <gensim.models.keyedvectors.Vocab at 0x7f727c1baeb8>,
#  'donaldtrump': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc278>,
#  'thaats': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc0f0>,
#  'kabyle': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc438>,
#  'delivering': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc1d0>,
#  'bony': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc390>,
#  'bao': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc550>,
#  'bio-data': <gensim.models.keyedvectors.Vocab at 0x7f727c1bcf28>,
#  'maker': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc5c0>,
#  'disks': <gensim.models.keyedvectors.Vocab at 0x7f727c1bcf98>,
#  'beanz': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc630>,
#  '4-6': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc9e8>,
#  'bie': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc6d8>,
#  'horribly': <gensim.models.keyedvectors.Vocab at 0x7f727c1bcac8>,
#  '15-18kw': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc7b8>,
#  'vocalization': <gensim.models.keyedvectors.Vocab at 0x7f727c1bcb38>,
#  'vetereans': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc320>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc240>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc208>,
#  'isie': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc4e0>,
#  'trys': <gensim.models.keyedvectors.Vocab at 0x7f727c1be1d0>,
#  'mod/crack': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc860>,
#  'animators': <gensim.models.keyedvectors.Vocab at 0x7f727c1be208>,
#  'tputh.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc908>,
#  'btech/mtech': <gensim.models.keyedvectors.Vocab at 0x7f727c1be240>,
#  'option': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc940>,
#  'florence': <gensim.models.keyedvectors.Vocab at 0x7f727c1be2e8>,
#  'reoccupied': <gensim.models.keyedvectors.Vocab at 0x7f727c1bc978>,
#  'hotpot': <gensim.models.keyedvectors.Vocab at 0x7f727c1be390>,
#  'roses': <gensim.models.keyedvectors.Vocab at 0x7f727c1be748>,
#  "'emotional": <gensim.models.keyedvectors.Vocab at 0x7f727c1bea90>,
#  'subjective': <gensim.models.keyedvectors.Vocab at 0x7f727c1be160>,
#  'microbial': <gensim.models.keyedvectors.Vocab at 0x7f727c1beac8>,
#  'drivetrain': <gensim.models.keyedvectors.Vocab at 0x7f727c1be198>,
#  'stretches': <gensim.models.keyedvectors.Vocab at 0x7f727c1beb00>,
#  'id': <gensim.models.keyedvectors.Vocab at 0x7f727c1be978>,
#  'major/career': <gensim.models.keyedvectors.Vocab at 0x7f727c1be438>,
#  'shinning': <gensim.models.keyedvectors.Vocab at 0x7f727c1be9b0>,
#  'lobotomies': <gensim.models.keyedvectors.Vocab at 0x7f727c1be908>,
#  'jody': <gensim.models.keyedvectors.Vocab at 0x7f727c1bec88>,
#  'radioshack': <gensim.models.keyedvectors.Vocab at 0x7f727c1bea58>,
#  'qps': <gensim.models.keyedvectors.Vocab at 0x7f727c1be9e8>,
#  'sholay': <gensim.models.keyedvectors.Vocab at 0x7f727c1be940>,
#  'spammer': <gensim.models.keyedvectors.Vocab at 0x7f727c1be048>,
#  '+\\ldots+2^': <gensim.models.keyedvectors.Vocab at 0x7f727c1bec50>,
#  'equity': <gensim.models.keyedvectors.Vocab at 0x7f727c1be470>,
#  'universally': <gensim.models.keyedvectors.Vocab at 0x7f727c1be358>,
#  'opencv': <gensim.models.keyedvectors.Vocab at 0x7f727c1be0f0>,
#  'g.tewani': <gensim.models.keyedvectors.Vocab at 0x7f727c1be898>,
#  'intellegent': <gensim.models.keyedvectors.Vocab at 0x7f727c1be128>,
#  'forgetful': <gensim.models.keyedvectors.Vocab at 0x7f727c1bee48>,
#  'jaypee/amity': <gensim.models.keyedvectors.Vocab at 0x7f727c1be4a8>,
#  'anti-terrorism': <gensim.models.keyedvectors.Vocab at 0x7f727c1bee80>,
#  'fx-4100': <gensim.models.keyedvectors.Vocab at 0x7f727c1be4e0>,
#  'scanners': <gensim.models.keyedvectors.Vocab at 0x7f727c1becf8>,
#  'log': <gensim.models.keyedvectors.Vocab at 0x7f727c1be550>,
#  'strong-willed': <gensim.models.keyedvectors.Vocab at 0x7f727c1beda0>,
#  'abash': <gensim.models.keyedvectors.Vocab at 0x7f727c1be828>,
#  'owens-illinois': <gensim.models.keyedvectors.Vocab at 0x7f727c1bef60>,
#  'sgot': <gensim.models.keyedvectors.Vocab at 0x7f727c1c0710>,
#  '7763': <gensim.models.keyedvectors.Vocab at 0x7f727c1befd0>,
#  'maternity.': <gensim.models.keyedvectors.Vocab at 0x7f727c1c01d0>,
#  'dermotology': <gensim.models.keyedvectors.Vocab at 0x7f727c1be5f8>,
#  'brussels': <gensim.models.keyedvectors.Vocab at 0x7f727c1c0208>,
#  'curiously': <gensim.models.keyedvectors.Vocab at 0x7f727c1be630>,
#  'auslan': <gensim.models.keyedvectors.Vocab at 0x7f727c1c02e8>,
#  'louis': <gensim.models.keyedvectors.Vocab at 0x7f727c1bec18>,
# ...
#  'allowance': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2710>,
#  'agianst': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2908>,
#  'g36c': <gensim.models.keyedvectors.Vocab at 0x7f727c1c27b8>,
#  'speridian': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2978>,
#  'nshit': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2828>,
#  'worker/freelancer': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2a20>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2da0>,
#  'lonavala': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2a58>,
#  'adipex': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2dd8>,
#  'whetstone': <gensim.models.keyedvectors.Vocab at 0x7f727c1c24e0>,
#  'danbilzerian': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2e10>,
#  'meida': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2128>,
#  'import.io': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2160>,
#  "'social": <gensim.models.keyedvectors.Vocab at 0x7f727c1c2c18>,
#  'non-linguistic': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4320>,
#  'xamrin': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2c88>,
#  'ites': <gensim.models.keyedvectors.Vocab at 0x7f727c1c40b8>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2d68>,
#  'curb': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4128>,
#  'lch': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2fd0>,
#  'shaded': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4198>,
#  'janis': <gensim.models.keyedvectors.Vocab at 0x7f727c1c20b8>,
#  '65.': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4240>,
#  'basic6.0': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2be0>,
#  'crawfish': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4cf8>,
#  '10000000': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2358>,
#  'booklet': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4d68>,
#  'menon': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2c50>,
#  'specifiers': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4e10>,
#  'pemdulum': <gensim.models.keyedvectors.Vocab at 0x7f727c1c2390>,
#  'troops': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4e48>,
#  'caracas': <gensim.models.keyedvectors.Vocab at 0x7f727c1c46d8>,
#  'herniated': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4518>,
#  'betablockers': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4710>,
#  'strapless': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4278>,
#  'concieved': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4748>,
#  'throw': <gensim.models.keyedvectors.Vocab at 0x7f727c1c41d0>,
#  'smsf': <gensim.models.keyedvectors.Vocab at 0x7f727c1c47f0>,
#  'oasis': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4588>,
#  'aneurysm': <gensim.models.keyedvectors.Vocab at 0x7f727c1c49e8>,
#  'marketability': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4a20>,
#  'blizzard': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4eb8>,
#  'app-like': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4390>,
#  'uttaranchal': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4ef0>,
#  "'der": <gensim.models.keyedvectors.Vocab at 0x7f727c1c43c8>,
#  'sunset': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4f98>,
#  'dushasana': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4b38>,
#  '99th': <gensim.models.keyedvectors.Vocab at 0x7f727c1c45c0>,
#  '.app': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4438>,
#  'dhammavinaya': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4940>,
#  'divinity': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4470>,
#  'chaat': <gensim.models.keyedvectors.Vocab at 0x7f727c1c49b0>,
#  'diffusion': <gensim.models.keyedvectors.Vocab at 0x7f727c1c44a8>,
#  'shortest': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4860>,
#  'majapahit': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4e80>,
#  'fundings': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4898>,
#  'messaged': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4ba8>,
#  'harvard.': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4908>,
#  'mandelbrot': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4be0>,
#  'adversary': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4a90>,
#  'imap4': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4c18>,
#  'wipro.what': <gensim.models.keyedvectors.Vocab at 0x7f727c1c69b0>,
#  'weaving': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4c50>,
#  'uptake': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6e10>,
#  'nda/na2': <gensim.models.keyedvectors.Vocab at 0x7f727c1c4cc0>,
#  'manch': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6eb8>,
#  'zte': <gensim.models.keyedvectors.Vocab at 0x7f727c1c44e0>,
#  'opaque': <gensim.models.keyedvectors.Vocab at 0x7f727c1c63c8>,
#  'rest/sleep': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6208>,
#  'produces': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6630>,
#  '/will': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6240>,
#  '21…': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6668>,
#  'mvc': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6278>,
#  'coils': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6748>,
#  'sprouted': <gensim.models.keyedvectors.Vocab at 0x7f727c1c62e8>,
#  "'carrying-on": <gensim.models.keyedvectors.Vocab at 0x7f727c1c6780>,
#  '1-propanol': <gensim.models.keyedvectors.Vocab at 0x7f727c1c60f0>,
#  'mobilefun.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1c67b8>,
#  'stalkbook': <gensim.models.keyedvectors.Vocab at 0x7f727c1c62b0>,
#  'mushers': <gensim.models.keyedvectors.Vocab at 0x7f727c1c67f0>,
#  'mumbai': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8cf8>,
#  'zenwatch': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6c18>,
#  'stewart': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8d30>,
#  "'chromophobia": <gensim.models.keyedvectors.Vocab at 0x7f727c1c6c88>,
#  'omnigraffle': <gensim.models.keyedvectors.Vocab at 0x7f727c1c86a0>,
#  'required': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6b38>,
#  'chandan': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8710>,
#  'etawah': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6be0>,
#  'arundinacea': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8780>,
#  'bookkeepers': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6d30>,
#  'booming': <gensim.models.keyedvectors.Vocab at 0x7f727c1c87f0>,
#  'constable': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6588>,
#  'store/sales': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8da0>,
#  '\\csc': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6ac8>,
#  'k=78': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8e10>,
#  'mits': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6160>,
#  'yakhni': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8b38>,
#  '143': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6ef0>,
#  'hoff': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8a20>,
#  'bayern': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6da0>,
#  'vous': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8a90>,
#  'immeasurable': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6550>,
#  'countries/cultures': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8ac8>,
#  'petsamo': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6080>,
#  'choosa': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8ef0>,
#  'loral': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6358>,
#  'website/web': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8f60>,
#  'rs.11,999': <gensim.models.keyedvectors.Vocab at 0x7f727c1c65f8>,
#  'drugged': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8f98>,
#  'wcdma': <gensim.models.keyedvectors.Vocab at 0x7f727c1c68d0>,
#  'nurturing/inside': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8860>,
#  'bizbilla.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6908>,
#  'mulcahy': <gensim.models.keyedvectors.Vocab at 0x7f727c1c80f0>,
#  'notified': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6f98>,
#  'fear': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8128>,
#  'blog/website': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6a58>,
#  'cvent': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8278>,
#  'senheisser': <gensim.models.keyedvectors.Vocab at 0x7f727c1c6a90>,
#  'noticeable': <gensim.models.keyedvectors.Vocab at 0x7f727c1c82e8>,
#  'embodied': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8080>,
#  'narayna': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8320>,
#  "'exact": <gensim.models.keyedvectors.Vocab at 0x7f727c1c8470>,
#  'coastline': <gensim.models.keyedvectors.Vocab at 0x7f727c1c83c8>,
#  'c+': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8518>,
#  'opamps': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8400>,
#  "'headphone": <gensim.models.keyedvectors.Vocab at 0x7f727c1c8588>,
#  'p-side': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca320>,
#  'skeletal': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8630>,
#  '^11': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca358>,
#  'chineese': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8908>,
#  'sikhism': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca390>,
#  'gamergate': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8ba8>,
#  'x²−3x+2=0': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca3c8>,
#  'n.s.i.t': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8be0>,
#  'turnedinto': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca4a8>,
#  '0−5': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8c18>,
#  'szeged': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca550>,
#  'glasgow': <gensim.models.keyedvectors.Vocab at 0x7f727c1c8c50>,
#  'jasprit': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca630>,
#  '*many*': <gensim.models.keyedvectors.Vocab at 0x7f727c1cac18>,
#  'tricks/tips': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca198>,
#  'ill-favored': <gensim.models.keyedvectors.Vocab at 0x7f727c1cacc0>,
#  'agrarian': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca240>,
#  '25/7': <gensim.models.keyedvectors.Vocab at 0x7f727c1cacf8>,
#  'grows': <gensim.models.keyedvectors.Vocab at 0x7f727c1caa20>,
#  'meal': <gensim.models.keyedvectors.Vocab at 0x7f727c1cad68>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca0b8>,
#  'appfutura.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca8d0>,
#  'that..': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca0f0>,
#  'dork': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca5c0>,
#  'wolverines': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca6d8>,
#  'non-creative': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca048>,
#  'theosophical': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca710>,
#  'langage': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca128>,
#  'ideo': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca780>,
#  'सुहस्ताः': <gensim.models.keyedvectors.Vocab at 0x7f727c1cae80>,
#  'brownish': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca7b8>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc5c0>,
#  'warsi': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca860>,
#  'quinby': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc3c8>,
#  'l14-30': <gensim.models.keyedvectors.Vocab at 0x7f727c1caef0>,
#  'dachshunds': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc080>,
#  'haka': <gensim.models.keyedvectors.Vocab at 0x7f727c1caf98>,
#  'bangladesh.can': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc358>,
#  'sms/e-mail': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca278>,
#  'i8262': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc9e8>,
#  'svb': <gensim.models.keyedvectors.Vocab at 0x7f727c1ca080>,
#  '7s': <gensim.models.keyedvectors.Vocab at 0x7f727c1cca58>,
#  'awesome/fun': <gensim.models.keyedvectors.Vocab at 0x7f727c1cadd8>,
#  'cmm': <gensim.models.keyedvectors.Vocab at 0x7f727c1cca90>,
#  'foreign-founding': <gensim.models.keyedvectors.Vocab at 0x7f727c1caeb8>,
#  '100-101': <gensim.models.keyedvectors.Vocab at 0x7f727c1ccb00>,
#  '3x3': <gensim.models.keyedvectors.Vocab at 0x7f727c1ccbe0>,
#  'air/fuel': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc5f8>,
#  '5.56': <gensim.models.keyedvectors.Vocab at 0x7f727c1ccc18>,
#  "'ganja": <gensim.models.keyedvectors.Vocab at 0x7f727c1ccb70>,
#  'gadget': <gensim.models.keyedvectors.Vocab at 0x7f727c1ccd30>,
#  '\\right': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc240>,
#  'pcb': <gensim.models.keyedvectors.Vocab at 0x7f727c1ccdd8>,
#  'ceos': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc2b0>,
#  'hooded': <gensim.models.keyedvectors.Vocab at 0x7f727c1ccf60>,
#  'kharagpur': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc668>,
#  'meteor': <gensim.models.keyedvectors.Vocab at 0x7f727c1ccf98>,
#  'eaten': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc828>,
#  'ni': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc898>,
#  'nakamichi': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc6d8>,
#  'r7': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc8d0>,
#  'annoys': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc6a0>,
#  'preliminary': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc198>,
#  '1977': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc780>,
#  'field/': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc208>,
#  'seer-up': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc470>,
#  'brewed': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce1d0>,
#  'isnt': <gensim.models.keyedvectors.Vocab at 0x7f727c1cc4a8>,
#  'sputum': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce278>,
#  'renters': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce588>,
#  'churma': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce8d0>,
#  'medal': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce5f8>,
#  'tth': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce940>,
#  'catholics/believers': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce668>,
#  '2799': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce978>,
#  'status/': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce710>,
#  'vs.': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce9e8>,
#  'infection': <gensim.models.keyedvectors.Vocab at 0x7f727c1cecc0>,
#  'patriated': <gensim.models.keyedvectors.Vocab at 0x7f727c1cea20>,
#  'balfour': <gensim.models.keyedvectors.Vocab at 0x7f727c1cecf8>,
#  'fool': <gensim.models.keyedvectors.Vocab at 0x7f727c1cec50>,
#  'tinderfling.com': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce0f0>,
#  'lasik/laser': <gensim.models.keyedvectors.Vocab at 0x7f727c1cec88>,
#  'soil.': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce470>,
#  'arashi': <gensim.models.keyedvectors.Vocab at 0x7f727c1cee80>,
#  'kpos': <gensim.models.keyedvectors.Vocab at 0x7f727c1cefd0>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7f727c1cef28>,
#  "'abram": <gensim.models.keyedvectors.Vocab at 0x7f727c1ced68>,
#  'byzantines': <gensim.models.keyedvectors.Vocab at 0x7f727c1cef60>,
#  'bhl': <gensim.models.keyedvectors.Vocab at 0x7f727c1ceda0>,
#  'varanasi': <gensim.models.keyedvectors.Vocab at 0x7f727c1d06d8>,
#  'divorces': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce518>,
#  'tambien': <gensim.models.keyedvectors.Vocab at 0x7f727c1d0128>,
#  '105hp': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce780>,
#  'reinforcement': <gensim.models.keyedvectors.Vocab at 0x7f727c1d0da0>,
#  'kushner': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce7f0>,
#  'maul': <gensim.models.keyedvectors.Vocab at 0x7f727c1d0860>,
#  'pints': <gensim.models.keyedvectors.Vocab at 0x7f727c1cee48>,
#  '15dayes': <gensim.models.keyedvectors.Vocab at 0x7f727c1d08d0>,
#  'demonoid': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce3c8>,
#  'bazzinotti': <gensim.models.keyedvectors.Vocab at 0x7f727c1d0908>,
#  'vgec': <gensim.models.keyedvectors.Vocab at 0x7f727c1ceb00>,
#  'deduct': <gensim.models.keyedvectors.Vocab at 0x7f727c1d0dd8>,
#  'vlkay': <gensim.models.keyedvectors.Vocab at 0x7f727c1cebe0>,
#  'motley': <gensim.models.keyedvectors.Vocab at 0x7f727c1d0e80>,
#  'rajnikanth': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce240>,
#  '2012-2014': <gensim.models.keyedvectors.Vocab at 0x7f727c1d0ef0>,
#  'pixotine': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce320>,
#  'variety': <gensim.models.keyedvectors.Vocab at 0x7f727c1d0f28>,
#  'rightest': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce048>,
#  '*begins*': <gensim.models.keyedvectors.Vocab at 0x7f727c1d0f60>,
#  'l200': <gensim.models.keyedvectors.Vocab at 0x7f727c1ce438>,
#  'dvi': <gensim.models.keyedvectors.Vocab at 0x7f727c1d0780>,
#  'throw-away': <gensim.models.keyedvectors.Vocab at 0x7f727c1d0828>,
#  'bs4': <gensim.models.keyedvectors.Vocab at 0x7f727c1d0b70>,
#  ...}

# %%
sw = stopwords.words('english')
def preprocess(q):
    q = q.lower()
    tokens = list(filter(lambda t: t in model.vocab and t not in sw, word_tokenize(q)))
    return tokens

# %%
model.wmdistance(preprocess(df.loc[0]['question1']), preprocess(df.loc[0]['question2']))
# Out:
# 0.6495802873639844

# %%
wm_distance = np.zeros(len(df))
for i in range(len(df)):
    wm_distance[i] = model.wmdistance(preprocess(df.loc[i]['question1']), preprocess(df.loc[i]['question2']))

# %%
wm_distance
# Out:
# array([ 0.64958029,  2.16065929,  2.32230936, ...,  1.99782613,
#         4.38424129,  0.        ])

# %%
df['wmd'] = wm_distance

# %%
df.ix[df['wmd'] == np.inf, 'wmd'] = 10000
df.to_csv('data/quora-train.csv', index=False)
# Out:
# /opt/miniconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.
